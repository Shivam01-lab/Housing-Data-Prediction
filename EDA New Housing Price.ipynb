# %%
#Import all library to be used in project
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the Data set
real_state_data=pd.read_csv("C:\\Users\\admin\\Desktop\\EDA Internship Project3\\housing_data.csv")
real_state_data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
#Count head
real_state_data.head(5)
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
#Find the shape of data set
real_state_data.shape
# Out:
# (1460, 81)

# %%
#Find the dimantion of data set
real_state_data.ndim
# Out:
# 2

# %%
# Find the summary of dataset 2
real_state_data.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
real_state_data.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
# ...

# %%
real_state_data.rename(columns = {'FireplaceQu' : 'Fireplace quality'}, inplace = True)

# %%
real_state_data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
real_state_data.rename(columns = {'MSSubClass' : 'Type of dwelling'}, inplace = True)

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0             SC60       RL           65     8450   Pave   NaN
# 1              1             SC20       RL           80     9600   Pave   NaN
# 2              2             SC60       RL           68    11250   Pave   NaN
# 3              3             SC70       RL           60     9550   Pave   NaN
# 4              4             SC60       RL           84    14260   Pave   NaN
# ...          ...              ...      ...          ...      ...    ...   ...
# 1455        1455             SC60       RL           62     7917   Pave   NaN
# 1456        1456             SC20       RL           85    13175   Pave   NaN
# 1457        1457             SC70       RL           66     9042   Pave   NaN
# 1458        1458             SC20       RL           68     9717   Pave   NaN
# 1459        1459             SC20       RL           75     9937   Pave   NaN
#
# ...

# %%
real_state_data.rename(columns = {'MSZoning' : 'General Zoning'}, inplace = True)

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling General Zoning  LotFrontage  LotArea Street  \
# 0              0             SC60             RL           65     8450   Pave
# 1              1             SC20             RL           80     9600   Pave
# 2              2             SC60             RL           68    11250   Pave
# 3              3             SC70             RL           60     9550   Pave
# 4              4             SC60             RL           84    14260   Pave
# ...          ...              ...            ...          ...      ...    ...
# 1455        1455             SC60             RL           62     7917   Pave
# 1456        1456             SC20             RL           85    13175   Pave
# 1457        1457             SC70             RL           66     9042   Pave
# 1458        1458             SC20             RL           68     9717   Pave
# 1459        1459             SC20             RL           75     9937   Pave
#
# ...

# %%
real_state_data.rename(columns = {'LotFrontage' : 'Linear feet of street'}, inplace = True)

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling General Zoning  Linear feet of street  \
# 0              0             SC60             RL                     65
# 1              1             SC20             RL                     80
# 2              2             SC60             RL                     68
# 3              3             SC70             RL                     60
# 4              4             SC60             RL                     84
# ...          ...              ...            ...                    ...
# 1455        1455             SC60             RL                     62
# 1456        1456             SC20             RL                     85
# 1457        1457             SC70             RL                     66
# 1458        1458             SC20             RL                     68
# 1459        1459             SC20             RL                     75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %%
real_state_data.rename(columns = {'LotArea' : 'Lot size in square feet'}, inplace = True)

# %%
real_state_data.head(20)
# Out:
#     Unnamed: 0 Type of dwelling General Zoning  Linear feet of street  \
# 0            0             SC60             RL                     65
# 1            1             SC20             RL                     80
# 2            2             SC60             RL                     68
# 3            3             SC70             RL                     60
# 4            4             SC60             RL                     84
# 5            5             SC50             RL                     85
# 6            6             SC20             RL                     75
# 7            7             SC60             RL                      0
# 8            8             SC50             RM                     51
# 9            9            SC190             RL                     50
# 10          10             SC20             RL                     70
# 11          11             SC60             RL                     85
# ...

# %% [markdown]
# #  Change all the Small Name with Real Name in General Zoning Columns
#    C   	Commercial
#    FV 	Floating Village Residential
#    I    	Industrial
#    RH	Residential High-Density
#    RL 	Residential Low-Density
#    RP	Residential Low-Density Park
#    RM	Residential Medium Density

# %%
real_state_data["General Zoning"]= real_state_data["General Zoning"].replace({"RL":"Residential Low-Density","RM":"Residential Medium Density","FV":"Floating Village Residential","RH":"Residential High-Density","RP":"Residential Low-Density Park","C":"Commercial","A":"Agriculture"})

# %%
 real_state_data.head()
# Out:
#    Unnamed: 0 Type of dwelling           General Zoning  \
# 0           0             SC60  Residential Low-Density
# 1           1             SC20  Residential Low-Density
# 2           2             SC60  Residential Low-Density
# 3           3             SC70  Residential Low-Density
# 4           4             SC60  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet Street Alley LotShape  \
# 0                     65                     8450   Pave   NaN      Reg
# 1                     80                     9600   Pave   NaN      Reg
# 2                     68                    11250   Pave   NaN      IR1
# 3                     60                     9550   Pave   NaN      IR1
# 4                     84                    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# ...

# %% [markdown]
# # Change all the Columns Name acoording to dictionary

# %%
real_state_data.rename(columns = {"Street" : 'Type of Acess Road to Property',"LotShape":"General shape of property","LandContour":"Flatness of the property","LotConfig":"Lot configuration","LandSlope":"Slope of property","Condition1":"Proximity to various conditions","HouseStyle":"Style of dwelling","OverallQual":"Rates the overall material","OverallCond":"Rates the overall condition of the house","YearBuilt":"Original construction date","RoofStyle":"Type of roof","RoofMatl":"Roof material","Exterior1st":"Exterior covering on the house","MasVnrArea":"Masonry veneer area in square feet","ExterQual":" Evaluates the quality of the material on the exterior","ExterCond":"Evaluates the present condition of the material on the exterior","BsmtQual":"Evaluates the height of the basement","BsmtCond":"Evaluate the general condition of the basement","BsmtExposure":"Refers to walkout or garden-level walls","BsmtFinType1":"Rating of basement finished area","BsmtFinSF1":"Type 1 finished square feet","BsmtFinSF2":"Type 2 finished square feet","BsmtUnfSF":"Unfinished square feet of basement area","TotalBsmtSF":"Total square feet of basement area","Heating":"Type of Heating","HeatingQC":"Heating quality and condition","CentralAir":"Central air conditioning","Electrical":"Electrical system","1stFlrSF":"First Floor square feet","2ndFlrSF":"econd-floor square feet","LowQualFinSF":"	Low-quality finished square feet","GrLivArea":"Above ground living area square feet","BsmtFullBath":"Basement full bathrooms","BsmtHalfBath":"Basement half bathrooms","FullBath":"Full bathrooms above grade","HalfBath":"Half Bathroom","Bedroom":"Bedrooms above grade (does NOT include basement bedrooms)","KitchenQual":"Kitchen Quality","TotRmsAbvGrd":"Total rooms above grade (does not include bathrooms)","Functional":"Home functionality (Assume typical unless deductions are warranted)","Fireplaces":"Number of fireplaces","FireplaceQu":"Fireplace quality","GarageType":"Garage location","GarageYrBlt":"The year garage was built","GarageCars":"Size of garage in car capacity","GarageArea":"Size of garage in square feet","GarageQual":"Garage quality","GarageCond":"Garage condition","WoodDeckSF":"Wood deck area in square feet","OpenPorchSF":"Open porch area in square feet","EnclosedPorch":"Enclosed porch area in square feet","3SsnPorch":"Three-season porch area in square feet","ScreenPorch":"Screen porch area in square feet","PoolArea":"Pool area in square feet","oolQC":"Pool quality","Fence":"Fence Quality","MiscFeature":"Miscellaneous feature not covered in other categories","MiscVal":"$Value of miscellaneous feature","MoSold":"Month Sold (MM)","YrSold":"Year Sold (YYYY)","Alley":"Type of alley access to property","BsmtFinType2":"Rating of basement finished area (if multiple types)","PoolQC":"Pool quality"}, inplace = True)

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling           General Zoning  \
# 0              0             SC60  Residential Low-Density
# 1              1             SC20  Residential Low-Density
# 2              2             SC60  Residential Low-Density
# 3              3             SC70  Residential Low-Density
# 4              4             SC60  Residential Low-Density
# ...          ...              ...                      ...
# 1455        1455             SC60  Residential Low-Density
# 1456        1456             SC20  Residential Low-Density
# 1457        1457             SC70  Residential Low-Density
# 1458        1458             SC20  Residential Low-Density
# 1459        1459             SC20  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# 0                        65                     8450
# 1                        80                     9600
# 2                        68                    11250
# ...

# %%
real_state_data["Type of Acess Road to Property"]= real_state_data["Type of Acess Road to Property"].replace({"Grvl":"Gravel","Pave":"Paved"})

# %%
real_state_data.head(5)
# Out:
#    Unnamed: 0 Type of dwelling           General Zoning  \
# 0           0             SC60  Residential Low-Density
# 1           1             SC20  Residential Low-Density
# 2           2             SC60  Residential Low-Density
# 3           3             SC70  Residential Low-Density
# 4           4             SC60  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
# 3                     60                     9550
# 4                     84                    14260
#
#   Type of Acess Road to Property Type of alley access to property  \
# 0                          Paved                              NaN
# 1                          Paved                              NaN
# 2                          Paved                              NaN
# ...

# %%
real_state_data["General shape of property"]= real_state_data["General shape of property"].replace({"Reg":"Regular","IR1":"Slightly irregular","IR2":"Moderately Irregular","IR3":"Irregular"})

# %%
real_state_data.head(5)
# Out:
#    Unnamed: 0 Type of dwelling           General Zoning  \
# 0           0             SC60  Residential Low-Density
# 1           1             SC20  Residential Low-Density
# 2           2             SC60  Residential Low-Density
# 3           3             SC70  Residential Low-Density
# 4           4             SC60  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
# 3                     60                     9550
# 4                     84                    14260
#
#   Type of Acess Road to Property Type of alley access to property  \
# 0                          Paved                              NaN
# 1                          Paved                              NaN
# 2                          Paved                              NaN
# ...

# %%
real_state_data["Fence Quality"]= real_state_data["Fence Quality"].replace({"MnPrv":"Minimum Privacy","GdPrv":"Good Privacy","Good Privacy":"Good Wood","MnWw":"Minimum Wood/Wire","NA":"No Fence"})

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling           General Zoning  \
# 0              0             SC60  Residential Low-Density
# 1              1             SC20  Residential Low-Density
# 2              2             SC60  Residential Low-Density
# 3              3             SC70  Residential Low-Density
# 4              4             SC60  Residential Low-Density
# ...          ...              ...                      ...
# 1455        1455             SC60  Residential Low-Density
# 1456        1456             SC20  Residential Low-Density
# 1457        1457             SC70  Residential Low-Density
# 1458        1458             SC20  Residential Low-Density
# 1459        1459             SC20  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# 0                        65                     8450
# 1                        80                     9600
# 2                        68                    11250
# ...

# %%
real_state_data["Utilities"]= real_state_data["Utilities"].replace({"AllPub":"All public Utilities (E,G,W,& S)","NoSewr":"Electricity, Gas, and Water (Septic Tank)","NoSeWa":"Electricity and Gas Only","ELO":"Electricity only"})

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling           General Zoning  \
# 0              0             SC60  Residential Low-Density
# 1              1             SC20  Residential Low-Density
# 2              2             SC60  Residential Low-Density
# 3              3             SC70  Residential Low-Density
# 4              4             SC60  Residential Low-Density
# ...          ...              ...                      ...
# 1455        1455             SC60  Residential Low-Density
# 1456        1456             SC20  Residential Low-Density
# 1457        1457             SC70  Residential Low-Density
# 1458        1458             SC20  Residential Low-Density
# 1459        1459             SC20  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# 0                        65                     8450
# 1                        80                     9600
# 2                        68                    11250
# ...

# %%
real_state_data["Type of alley access to property"]= real_state_data["Type of alley access to property"].replace({"Grvl":"Gravel","Pave":"Paved","NA":"No alley access"})

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling           General Zoning  \
# 0              0             SC60  Residential Low-Density
# 1              1             SC20  Residential Low-Density
# 2              2             SC60  Residential Low-Density
# 3              3             SC70  Residential Low-Density
# 4              4             SC60  Residential Low-Density
# ...          ...              ...                      ...
# 1455        1455             SC60  Residential Low-Density
# 1456        1456             SC20  Residential Low-Density
# 1457        1457             SC70  Residential Low-Density
# 1458        1458             SC20  Residential Low-Density
# 1459        1459             SC20  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# 0                        65                     8450
# 1                        80                     9600
# 2                        68                    11250
# ...

# %%
real_state_data["Lot configuration"]= real_state_data["Lot configuration"].replace({"Inside":"Inside lot","FR2":"Frontage on 2 sides of the property","FR3":"Frontage on 3 sides of the property"})

# %%
real_state_data.head(5)
# Out:
#    Unnamed: 0 Type of dwelling           General Zoning  \
# 0           0             SC60  Residential Low-Density
# 1           1             SC20  Residential Low-Density
# 2           2             SC60  Residential Low-Density
# 3           3             SC70  Residential Low-Density
# 4           4             SC60  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
# 3                     60                     9550
# 4                     84                    14260
#
#   Type of Acess Road to Property Type of alley access to property  \
# 0                          Paved                              NaN
# 1                          Paved                              NaN
# 2                          Paved                              NaN
# ...

# %%
real_state_data["Lot configuration"]
# Out:
# 0                                Inside lot
# 1       Frontage on 2 sides of the property
# 2                                Inside lot
# 3                                    Corner
# 4       Frontage on 2 sides of the property
#                        ...
# 1455                             Inside lot
# 1456                             Inside lot
# 1457                             Inside lot
# 1458                             Inside lot
# 1459                             Inside lot
# Name: Lot configuration, Length: 1460, dtype: object

# %%
real_state_data["Slope of property"]= real_state_data["Slope of property"].replace({"Gtl":"Gentle slope","Mod":"Moderate Slope","Sev":"Severe Slope"})

# %%
real_state_data["Slope of property"]
# Out:
# 0       Gentle slope
# 1       Gentle slope
# 2       Gentle slope
# 3       Gentle slope
# 4       Gentle slope
#             ...
# 1455    Gentle slope
# 1456    Gentle slope
# 1457    Gentle slope
# 1458    Gentle slope
# 1459    Gentle slope
# Name: Slope of property, Length: 1460, dtype: object

# %%
real_state_data["Neighborhood"]= real_state_data["Neighborhood"].replace({"Blmngtn":"Bloomington Heights","Blueste":"Bluestem","BrDale":"Briardale","BrkSide":"Brookside","ClearCr":"Clear Creek","CollgCr":"College Creek","Crawfor":"Crawford","IDOTRR":"Iowa DOT and Rail Road","MeadowV":"Meadow Village","Names":"North Ames","NoRidge":"Northridge","NPkVil":"Northpark Villa","NridgHt":"Northridge Heights"})

# %%
real_state_data
# Out:
#       Unnamed: 0 Type of dwelling           General Zoning  \
# 0              0             SC60  Residential Low-Density
# 1              1             SC20  Residential Low-Density
# 2              2             SC60  Residential Low-Density
# 3              3             SC70  Residential Low-Density
# 4              4             SC60  Residential Low-Density
# ...          ...              ...                      ...
# 1455        1455             SC60  Residential Low-Density
# 1456        1456             SC20  Residential Low-Density
# 1457        1457             SC70  Residential Low-Density
# 1458        1458             SC20  Residential Low-Density
# 1459        1459             SC20  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# 0                        65                     8450
# 1                        80                     9600
# 2                        68                    11250
# ...

# %%
real_state_data["Neighborhood"]
# Out:
# 0       College Creek
# 1             Veenker
# 2       College Creek
# 3            Crawford
# 4          Northridge
#             ...
# 1455          Gilbert
# 1456           NWAmes
# 1457         Crawford
# 1458            NAmes
# 1459          Edwards
# Name: Neighborhood, Length: 1460, dtype: object

# %%
real_state_data["Type of dwelling"]= real_state_data["Type of dwelling"].replace({"SC20": "1-STORY 1946 & NEWER ALL STYLES",
    "SC30": "1-STORY 1945 & OLDER",
    "SC40": "1-STORY W/FINISHED ATTIC ALL AGES",
    "SC45": "1-1/2 STORY - UNFINISHED ALL AGES",
    "SC50": "1-1/2 STORY FINISHED ALL AGES",
    "SC60": "2-STORY 1946 & NEWER",
    "SC70": "2-STORY 1945 & OLDER",
    "SC75": "2-1/2 STORY ALL AGES",
    "SC80": "SPLIT OR MULTI-LEVEL",
    "SC90": "DUPLEX - ALL STYLES AND AGES",
    "SC120": "1-STORY PUD (Planned Unit Development) - 1946 & NEWER",
    "SC150": "1-1/2 STORY PUD - ALL AGES",
    "SC160": "2-STORY PUD - 1946 & NEWER",
    "SC180": "PUD - MULTILEVEL - INCL SPLIT LEV/FOYER",
    "SC190": "2 FAMILY CONVERSION - ALL STYLES AND AGES"})

# %%
real_state_data.head(3)
# Out:
#    Unnamed: 0                 Type of dwelling           General Zoning  \
# 0           0             2-STORY 1946 & NEWER  Residential Low-Density
# 1           1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2           2             2-STORY 1946 & NEWER  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
#
#   Type of Acess Road to Property Type of alley access to property  \
# 0                          Paved                              NaN
# 1                          Paved                              NaN
# 2                          Paved                              NaN
#
#   General shape of property Flatness of the property  \
# 0                   Regular                      Lvl
# 1                   Regular                      Lvl
# ...

# %%
real_state_data.columns
# Out:
# Index(['Unnamed: 0', 'Type of dwelling', 'General Zoning',
#        'Linear feet of street', 'Lot size in square feet',
#        'Type of Acess Road to Property', 'Type of alley access to property',
#        'General shape of property', 'Flatness of the property', 'Utilities',
#        'Lot configuration', 'Slope of property', 'Neighborhood',
#        'Proximity to various conditions', 'Condition2', 'BldgType',
#        'Style of dwelling', 'Rates the overall material',
#        'Rates the overall condition of the house',
#        'Original construction date', 'YearRemodAdd', 'Type of roof',
#        'Roof material', 'Exterior covering on the house', 'Exterior2nd',
#        'MasVnrType', 'Masonry veneer area in square feet',
#        ' Evaluates the quality of the material on the exterior',
#        'Evaluates the present condition of the material on the exterior',
#        'Foundation', 'Evaluates the height of the basement',
# ...

# %%
real_state_data["Style of dwelling"]= real_state_data["Style of dwelling"].replace(
    {"1Story":"One story",
    "1.5Fin":"One and one-half story &2nd level finished",
    "1.5Unf":"One and one-half story&2nd level unfinished",
    "2Story":"Two-story",
    "2.5Fin":"Two and one-half story&2nd level finished",
    "2.5Unf":"Two and one-half story&2nd level unfinished",
    "SFoyer":"Split Foyer",
    "SLvl":"Split Level"})

# %%
real_state_data["Style of dwelling"]
# Out:
# 0       Two-story
# 1       One story
# 2       Two-story
# 3       Two-story
# 4       Two-story
#           ...
# 1455    Two-story
# 1456    One story
# 1457    Two-story
# 1458    One story
# 1459    One story
# Name: Style of dwelling, Length: 1460, dtype: object

# %%
real_state_data["Rates the overall material"]= real_state_data['Rates the overall material'].replace({ 10:"Very Excellent",
    9:"Excellent",
    8:"Very Good",
    7:"Good",
    6:"Above Average",
    5:"Average",
    4:"Below Average",
    3:"Fair",
    2:"Poor",
    1:"Very Poor"})

# %%
real_state_data["Rates the overall material"]
# Out:
# 0                Good
# 1       Above Average
# 2                Good
# 3                Good
# 4           Very Good
#             ...
# 1455    Above Average
# 1456    Above Average
# 1457             Good
# 1458          Average
# 1459          Average
# Name: Rates the overall material, Length: 1460, dtype: object

# %%
real_state_data
# Out:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# ...

# %%
real_state_data["Rates the overall condition of the house"]= real_state_data['Rates the overall condition of the house'].replace({ 10:"Very Excellent",
    9:"Excellent",
    8:"Very Good",
    7:"Good",
    6:"Above Average",
    5:"Average",
    4:"Below Average",
    3:"Fair",
    2:"Poor",
    1:"Very Poor"})

# %%
real_state_data["Rates the overall condition of the house"]
# Out:
# 0             Average
# 1           Very Good
# 2             Average
# 3             Average
# 4             Average
#             ...
# 1455          Average
# 1456    Above Average
# 1457        Excellent
# 1458    Above Average
# 1459    Above Average
# Name: Rates the overall condition of the house, Length: 1460, dtype: object

# %%
real_state_data["Roof material"]= real_state_data["Roof material"].replace({'ClyTile':'Clay or Tile',
    'CompShg':'Standard (Composite) Shingle',
    'Membran':'Membrane',
    'Metal':'Metal',
    'Roll':'Roll',
    'Tar&Grv':'Gravel & Tar',
    'WdShake':'Wood Shakes',
    'WdShngl':'Wood Shingles'})

# %%
real_state_data["Roof material"]
# Out:
# 0       Standard (Composite) Shingle
# 1       Standard (Composite) Shingle
# 2       Standard (Composite) Shingle
# 3       Standard (Composite) Shingle
# 4       Standard (Composite) Shingle
#                     ...
# 1455    Standard (Composite) Shingle
# 1456    Standard (Composite) Shingle
# 1457    Standard (Composite) Shingle
# 1458    Standard (Composite) Shingle
# 1459    Standard (Composite) Shingle
# Name: Roof material, Length: 1460, dtype: object

# %%
real_state_data["Exterior covering on the house"]= real_state_data["Exterior covering on the house"].replace({'AsbShng':'Asbestos Shingles',
    'AsphShn':'Asphalt Shingles',
    'BrkComm':'Brick Common',
    'BrkFace':'Brick Face',
    'CBlock':'Cinder Block',
    'CemntBd':'Cement Board',
    'HdBoard':'Hard Board',
    'ImStucc':'Imitation Stucco',
    'MetalSd':'Metal Siding',
    'Other':'Other',
    'Plywood':'Plywood',
    'PreCast':'PreCast',
    'Stone':'Stone',
    'Stucco':'Stucco',
    'VinylSd':'Vinyl Siding',
    'WdSdng':'Wood Siding',
    'WdShing':'Wood Shingles'})

# %%
real_state_data["Exterior covering on the house"]
# Out:
# 0       Vinyl Siding
# 1       Metal Siding
# 2       Vinyl Siding
# 3            Wd Sdng
# 4       Vinyl Siding
#             ...
# 1455    Vinyl Siding
# 1456         Plywood
# 1457    Cement Board
# 1458    Metal Siding
# 1459      Hard Board
# Name: Exterior covering on the house, Length: 1460, dtype: object

# %%
real_state_data["Evaluates the present condition of the material on the exterior"]= real_state_data["Evaluates the present condition of the material on the exterior"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Average/Typical',
    'Fa':'Fair',
    'Po':'Poor'})

# %%
real_state_data["Evaluates the height of the basement"]= real_state_data["Evaluates the height of the basement"].replace({'Ex':'Excellent (100+ inches)',
    'Gd':'Good (90-99 inches)',
    'TA':'Typical (80-89 inches)',
    'Fa':'Fair (70-79 inches)',
    'Po':'Poor (<70 inches)',
    'NA':'No Basement'})

# %%
real_state_data["Evaluates the height of the basement"]
# Out:
# 0          Good (90-99 inches)
# 1          Good (90-99 inches)
# 2          Good (90-99 inches)
# 3       Typical (80-89 inches)
# 4          Good (90-99 inches)
#                  ...
# 1455       Good (90-99 inches)
# 1456       Good (90-99 inches)
# 1457    Typical (80-89 inches)
# 1458    Typical (80-89 inches)
# 1459    Typical (80-89 inches)
# Name: Evaluates the height of the basement, Length: 1460, dtype: object

# %%
real_state_data["Evaluate the general condition of the basement"]= real_state_data["Evaluate the general condition of the basement"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Typical - slight dampness allowed',
    'Fa':'Fair - dampness or some cracking or settling',
    'Po':'Poor - Severe cracking, settling, or wetness',
    'NA':'No Basement'})

# %%
real_state_data["Evaluate the general condition of the basement"]
# Out:
# 0       Typical - slight dampness allowed
# 1       Typical - slight dampness allowed
# 2       Typical - slight dampness allowed
# 3                                    Good
# 4       Typical - slight dampness allowed
#                       ...
# 1455    Typical - slight dampness allowed
# 1456    Typical - slight dampness allowed
# 1457                                 Good
# 1458    Typical - slight dampness allowed
# 1459    Typical - slight dampness allowed
# Name: Evaluate the general condition of the basement, Length: 1460, dtype: object

# %%
real_state_data["Refers to walkout or garden-level walls"]= real_state_data["Refers to walkout or garden-level walls"].replace({ 'Gd':'Good Exposure',
    'Av':'Average Exposure (split levels or foyers typically score average or above)',
    'Mn':'Minimum Exposure',
    'No':'No Exposure',
    'NA':'No Basement'})

# %%
real_state_data["Refers to walkout or garden-level walls"]
# Out:
# 0                                             No Exposure
# 1                                           Good Exposure
# 2                                        Minimum Exposure
# 3                                             No Exposure
# 4       Average Exposure (split levels or foyers typic...
#                               ...
# 1455                                          No Exposure
# 1456                                          No Exposure
# 1457                                          No Exposure
# 1458                                     Minimum Exposure
# 1459                                          No Exposure
# Name: Refers to walkout or garden-level walls, Length: 1460, dtype: object

# %%
real_state_data["Rating of basement finished area"]= real_state_data["Rating of basement finished area"].replace({ 'GLQ':'Good Living Quarters',
    'ALQ':'Average Living Quarters',
    'BLQ':'Below Average Living Quarters',
    'Rec':'Average Rec Room',
    'LwQ':'Low Quality',
    'Unf':'Unfinished',
    'NA':'No Basement'})

# %%
real_state_data["Rating of basement finished area"]
# Out:
# 0                Good Living Quarters
# 1             Average Living Quarters
# 2                Good Living Quarters
# 3             Average Living Quarters
# 4                Good Living Quarters
#                     ...
# 1455                       Unfinished
# 1456          Average Living Quarters
# 1457             Good Living Quarters
# 1458             Good Living Quarters
# 1459    Below Average Living Quarters
# Name: Rating of basement finished area, Length: 1460, dtype: object

# %%
real_state_data.columns
# Out:
# Index(['Unnamed: 0', 'Type of dwelling', 'General Zoning',
#        'Linear feet of street', 'Lot size in square feet',
#        'Type of Acess Road to Property', 'Type of alley access to property',
#        'General shape of property', 'Flatness of the property', 'Utilities',
#        'Lot configuration', 'Slope of property', 'Neighborhood',
#        'Proximity to various conditions', 'Condition2', 'BldgType',
#        'Style of dwelling', 'Rates the overall material',
#        'Rates the overall condition of the house',
#        'Original construction date', 'YearRemodAdd', 'Type of roof',
#        'Roof material', 'Exterior covering on the house', 'Exterior2nd',
#        'MasVnrType', 'Masonry veneer area in square feet',
#        ' Evaluates the quality of the material on the exterior',
#        'Evaluates the present condition of the material on the exterior',
#        'Foundation', 'Evaluates the height of the basement',
# ...

# %%
real_state_data["Rating of basement finished area (if multiple types)"]= real_state_data["Rating of basement finished area (if multiple types)"].replace({ 'GLQ':'Good Living Quarters',
    'ALQ':'Average Living Quarters',
    'BLQ':'Below Average Living Quarters',
    'Rec':'Average Rec Room',
    'LwQ':'Low Quality',
    'Unf':'Unfinished',
    'NA':'No Basement'})

# %%
real_state_data["Rating of basement finished area (if multiple types)"]
# Out:
# 0             Unfinished
# 1             Unfinished
# 2             Unfinished
# 3             Unfinished
# 4             Unfinished
#               ...
# 1455          Unfinished
# 1456    Average Rec Room
# 1457          Unfinished
# 1458    Average Rec Room
# 1459         Low Quality
# Name: Rating of basement finished area (if multiple types), Length: 1460, dtype: object

# %%
real_state_data["Type of Heating"]= real_state_data["Type of Heating"].replace({ 'Floor':'Floor Furnace',
    'GasA':'Gas forced warm air furnace',
    'GasW':'Gas hot water or steam heat',
    'Grav':'Gravity furnace',
    'OthW':'Hot water or steam heat other than gas',
    'Wall':'Wall furnace'
})

# %%
real_state_data["Type of Heating"]
# Out:
# 0       Gas forced warm air furnace
# 1       Gas forced warm air furnace
# 2       Gas forced warm air furnace
# 3       Gas forced warm air furnace
# 4       Gas forced warm air furnace
#                    ...
# 1455    Gas forced warm air furnace
# 1456    Gas forced warm air furnace
# 1457    Gas forced warm air furnace
# 1458    Gas forced warm air furnace
# 1459    Gas forced warm air furnace
# Name: Type of Heating, Length: 1460, dtype: object

# %%
real_state_data["Heating quality and condition"]= real_state_data["Heating quality and condition"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Average/Typical',
    'Fa':'Fair',
    'Po':'Poor'})

# %%
real_state_data["Heating quality and condition"]
# Out:
# 0             Excellent
# 1             Excellent
# 2             Excellent
# 3                  Good
# 4             Excellent
#              ...
# 1455          Excellent
# 1456    Average/Typical
# 1457          Excellent
# 1458               Good
# 1459               Good
# Name: Heating quality and condition, Length: 1460, dtype: object

# %%
real_state_data["Electrical system"]= real_state_data["Electrical system"].replace({
    'SBrkr':'Standard Circuit Breakers & Romex',
    'FuseA':'Fuse Box over 60 AMP and all Romex wiring (Average)',
    'FuseF':'60 AMP Fuse Box and mostly Romex wiring (Fair)',
    'FuseP':'60 AMP Fuse Box and mostly knob & tube wiring (poor)',
    'Mix':'Mixed'

})

# %%
real_state_data["Electrical system"]
# Out:
# 0                       Standard Circuit Breakers & Romex
# 1                       Standard Circuit Breakers & Romex
# 2                       Standard Circuit Breakers & Romex
# 3                       Standard Circuit Breakers & Romex
# 4                       Standard Circuit Breakers & Romex
#                               ...
# 1455                    Standard Circuit Breakers & Romex
# 1456                    Standard Circuit Breakers & Romex
# 1457                    Standard Circuit Breakers & Romex
# 1458    Fuse Box over 60 AMP and all Romex wiring (Ave...
# 1459                    Standard Circuit Breakers & Romex
# Name: Electrical system, Length: 1460, dtype: object

# %%
real_state_data["Kitchen Quality"]= real_state_data["Kitchen Quality"].replace({ 'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Typical/Average',
    'Fa':'Fair',
    'Po':'Poor'})

# %%
real_state_data["Kitchen Quality"]
# Out:
# 0                  Good
# 1       Typical/Average
# 2                  Good
# 3                  Good
# 4                  Good
#              ...
# 1455    Typical/Average
# 1456    Typical/Average
# 1457               Good
# 1458               Good
# 1459    Typical/Average
# Name: Kitchen Quality, Length: 1460, dtype: object

# %%
real_state_data["Home functionality (Assume typical unless deductions are warranted)"]= real_state_data["Home functionality (Assume typical unless deductions are warranted)"].replace({'Typ':'Typical Functionality',
    'Min1':'Minor Deductions 1',
    'Min2':'Minor Deductions 2',
    'Mod':'Moderate Deductions',
    'Maj1':'Major Deductions 1',
    'Maj2':'Major Deductions 2',
    'Sev':'Severely Damaged',
    'Sal':'Salvage only'})

# %%
real_state_data["Home functionality (Assume typical unless deductions are warranted)"]
# Out:
# 0       Typical Functionality
# 1       Typical Functionality
# 2       Typical Functionality
# 3       Typical Functionality
# 4       Typical Functionality
#                 ...
# 1455    Typical Functionality
# 1456       Minor Deductions 1
# 1457    Typical Functionality
# 1458    Typical Functionality
# 1459    Typical Functionality
# Name: Home functionality (Assume typical unless deductions are warranted), Length: 1460, dtype: object

# %%
real_state_data["Fireplace quality"]= real_state_data["Fireplace quality"].replace({'Ex':'Excellent - Exceptional Masonry Fireplace',
    'Gd':'Good - Masonry Fireplace on the main level',
    'TA':'Average - Prefabricated Fireplace in the main living area or Masonry Fireplace in the basement',
    'Fa':'Fair - Prefabricated Fireplace in the basement',
    'Po':'Poor - Ben Franklin Stove',
    'NA':'No Fireplace'})

# %%
real_state_data["Fireplace quality"]
# Out:
# 0                                                      No
# 1       Average - Prefabricated Fireplace in the main ...
# 2       Average - Prefabricated Fireplace in the main ...
# 3              Good - Masonry Fireplace on the main level
# 4       Average - Prefabricated Fireplace in the main ...
#                               ...
# 1455    Average - Prefabricated Fireplace in the main ...
# 1456    Average - Prefabricated Fireplace in the main ...
# 1457           Good - Masonry Fireplace on the main level
# 1458                                                   No
# 1459                                                   No
# Name: Fireplace quality, Length: 1460, dtype: object

# %%
real_state_data["Garage location"]= real_state_data["Garage location"].replace({'2Types':'More than one type of garage',
    'Attchd':'Attached to the home',
    'Basment':'Basement Garage',
    'BuiltIn':'Built-In (Garage part of the house - typically has room above the garage)',
    'CarPort':'Car Port',
    'Detchd':'Detached from home',
    'NA':'No Garage'})

# %%
real_state_data["GarageFinish"]= real_state_data["GarageFinish"].replace({'Fin':'Finished',
    'RFn':'Rough Finished',
    'Unf':'Unfinished',
    'NA':'No Garage'})

# %%
real_state_data["Garage quality"]= real_state_data["Garage quality"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Typical/Average',
    'Fa':'Fair',
    'Po':'Poor',
    'NA':'No Garage'})

# %%
real_state_data["Garage condition"]= real_state_data["Garage condition"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Typical/Average',
    'Fa':'Fair',
    'Po':'Poor',
    'NA':'No Garage'})

# %%
real_state_data["PavedDrive"]= real_state_data["PavedDrive"].replace({'Y':'Paved',
    'P':'Partial Pavement',
    'N':'Dirt/Gravel'})

# %%
real_state_data["Pool quality"]= real_state_data["Pool quality"].replace({'Ex':'Excellent',
    'Gd':'Good',
    'TA':'Average/Typical',
    'Fa':'Fair',
    'NA':'No Pool'})

# %%
real_state_data["Fence Quality"]= real_state_data["Fence Quality"].replace({'GdPrv':'Good Privacy',
    'MnPrv':'Minimum Privacy',
    'GdWo':'Good Wood',
    'MnWw':'Minimum Wood/Wire',
    'NA':'No Fence'})

# %%
real_state_data["Miscellaneous feature not covered in other categories"]= real_state_data["Miscellaneous feature not covered in other categories"].replace({'Elev':'Elevator',
    'Gar2':'2nd Garage (if not described in garage section)',
    'Othr':'Other',
    'Shed':'Shed (over 100 SF)',
    'TenC':'Tennis Court',
    'NA':'None'})

# %%
real_state_data["SaleType"]= real_state_data["SaleType"].replace({'WD':'Warranty Deed - Conventional',
    'CWD':'Warranty Deed - Cash',
    'VWD':'Warranty Deed - VA Loan',
    'New':'Home just constructed and sold',
    'COD':'Court Officer Deed/Estate',
    'Con':'Contract 15% Down payment regular terms',
    'ConLw':'Contract Low Down payment and low interest',
    'ConLI':'Contract Low Interest',
    'ConLD':'Contract Low Down',
    'Oth':'Other'})

# %%
real_state_data["SaleCondition"]= real_state_data["SaleCondition"].replace({'Normal':'Normal Sale',
    'Abnorml':'Abnormal Sale - trade, foreclosure, short sale',
    'AdjLand':'Adjoining Land Purchase',
    'Alloca':'Allocation - two linked properties with separate deeds, typically condo with a garage unit',
    'Family':'Sale between family members',
    'Partial':'Home was not completed when last assessed (associated with New Homes)'})

# %%
real_state_data.iloc[:3,3:80]
# Out:
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
#
#   Type of Acess Road to Property Type of alley access to property  \
# 0                          Paved                              NaN
# 1                          Paved                              NaN
# 2                          Paved                              NaN
#
#   General shape of property Flatness of the property  \
# 0                   Regular                      Lvl
# 1                   Regular                      Lvl
# 2        Slightly irregular                      Lvl
#
#                           Utilities                    Lot configuration  \
# 0  All public Utilities (E,G,W,& S)                           Inside lot
# 1  All public Utilities (E,G,W,& S)  Frontage on 2 sides of the property
# ...

# %%
real_state_data
# Out:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# ...

# %%
real_state_data
# Out:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# ...

# %%
real_state_data
# Out:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# ...

# %%
real_state_data.iloc[:5,0:80].to_dict()
# Out:
# {'Unnamed: 0': {0: 0, 1: 1, 2: 2, 3: 3, 4: 4},
#  'Type of dwelling': {0: '2-STORY 1946 & NEWER',
#   1: '1-STORY 1946 & NEWER ALL STYLES',
#   2: '2-STORY 1946 & NEWER',
#   3: '2-STORY 1945 & OLDER',
#   4: '2-STORY 1946 & NEWER'},
#  'General Zoning': {0: 'Residential Low-Density',
#   1: 'Residential Low-Density',
#   2: 'Residential Low-Density',
#   3: 'Residential Low-Density',
#   4: 'Residential Low-Density'},
#  'Linear feet of street': {0: 65, 1: 80, 2: 68, 3: 60, 4: 84},
#  'Lot size in square feet': {0: 8450, 1: 9600, 2: 11250, 3: 9550, 4: 14260},
#  'Type of Acess Road to Property': {0: 'Paved',
#   1: 'Paved',
#   2: 'Paved',
#   3: 'Paved',
#   4: 'Paved'},
#  'Type of alley access to property': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'General shape of property': {0: 'Regular',
#   1: 'Regular',
#   2: 'Slightly irregular',
#   3: 'Slightly irregular',
#   4: 'Slightly irregular'},
#  'Flatness of the property': {0: 'Lvl',
#   1: 'Lvl',
#   2: 'Lvl',
# ...

# %%
real_state_data.isnull().sum().to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'Type of dwelling': 0,
#  'General Zoning': 0,
#  'Linear feet of street': 0,
#  'Lot size in square feet': 0,
#  'Type of Acess Road to Property': 0,
#  'Type of alley access to property': 1369,
#  'General shape of property': 0,
#  'Flatness of the property': 0,
#  'Utilities': 0,
#  'Lot configuration': 0,
#  'Slope of property': 0,
#  'Neighborhood': 0,
#  'Proximity to various conditions': 0,
#  'Condition2': 0,
#  'BldgType': 0,
#  'Style of dwelling': 0,
#  'Rates the overall material': 0,
#  'Rates the overall condition of the house': 0,
#  'Original construction date': 0,
#  'YearRemodAdd': 0,
#  'Type of roof': 0,
#  'Roof material': 0,
#  'Exterior covering on the house': 0,
#  'Exterior2nd': 0,
#  'MasVnrType': 872,
#  'Masonry veneer area in square feet': 0,
#  ' Evaluates the quality of the material on the exterior': 0,
#  'Evaluates the present condition of the material on the exterior': 0,
#  'Foundation': 0,
# ...

# %%
real_state_data = real_state_data.drop("Type of alley access to property", axis='columns')

# %%
real_state_data
# Out:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
#       Linear feet of street  Lot size in square feet  \
# ...

# %%
real_state_data = real_state_data.drop("MasVnrType", axis='columns')

# %%
real_state_data.isnull().sum().to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'Type of dwelling': 0,
#  'General Zoning': 0,
#  'Linear feet of street': 0,
#  'Lot size in square feet': 0,
#  'Type of Acess Road to Property': 0,
#  'General shape of property': 0,
#  'Flatness of the property': 0,
#  'Utilities': 0,
#  'Lot configuration': 0,
#  'Slope of property': 0,
#  'Neighborhood': 0,
#  'Proximity to various conditions': 0,
#  'Condition2': 0,
#  'BldgType': 0,
#  'Style of dwelling': 0,
#  'Rates the overall material': 0,
#  'Rates the overall condition of the house': 0,
#  'Original construction date': 0,
#  'YearRemodAdd': 0,
#  'Type of roof': 0,
#  'Roof material': 0,
#  'Exterior covering on the house': 0,
#  'Exterior2nd': 0,
#  'Masonry veneer area in square feet': 0,
#  ' Evaluates the quality of the material on the exterior': 0,
#  'Evaluates the present condition of the material on the exterior': 0,
#  'Foundation': 0,
#  'Evaluates the height of the basement': 0,
#  'Evaluate the general condition of the basement': 0,
# ...

# %%
real_state_data["Electrical system"].mode()
# Out:
# 0    Standard Circuit Breakers & Romex
# Name: Electrical system, dtype: object

# %%
column_name="Electrical system"
mode_value=real_state_data["Electrical system"].mode()[0]
real_state_data[column_name].fillna(mode_value,inplace=True)
print("Data after fill missing value using mode fn {}: \n{}".format(column_name,real_state_data))
# Out:
# Data after fill missing value using mode fn Electrical system:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
#
# ...

# %%
real_state_data.isnull().sum().to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'Type of dwelling': 0,
#  'General Zoning': 0,
#  'Linear feet of street': 0,
#  'Lot size in square feet': 0,
#  'Type of Acess Road to Property': 0,
#  'General shape of property': 0,
#  'Flatness of the property': 0,
#  'Utilities': 0,
#  'Lot configuration': 0,
#  'Slope of property': 0,
#  'Neighborhood': 0,
#  'Proximity to various conditions': 0,
#  'Condition2': 0,
#  'BldgType': 0,
#  'Style of dwelling': 0,
#  'Rates the overall material': 0,
#  'Rates the overall condition of the house': 0,
#  'Original construction date': 0,
#  'YearRemodAdd': 0,
#  'Type of roof': 0,
#  'Roof material': 0,
#  'Exterior covering on the house': 0,
#  'Exterior2nd': 0,
#  'Masonry veneer area in square feet': 0,
#  ' Evaluates the quality of the material on the exterior': 0,
#  'Evaluates the present condition of the material on the exterior': 0,
#  'Foundation': 0,
#  'Evaluates the height of the basement': 0,
#  'Evaluate the general condition of the basement': 0,
# ...

# %%
real_state_data["The year garage was built"].mode()
# Out:
# 0    2005.0
# Name: The year garage was built, dtype: float64

# %%
column_name="The year garage was built"
mode_value=real_state_data["The year garage was built"].mode()[0]
real_state_data[column_name].fillna(mode_value,inplace=True)
print("Data after fill missing value using mode fn {}: \n{}".format(column_name,real_state_data))
# Out:
# Data after fill missing value using mode fn The year garage was built:
#       Unnamed: 0                 Type of dwelling           General Zoning  \
# 0              0             2-STORY 1946 & NEWER  Residential Low-Density
# 1              1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2              2             2-STORY 1946 & NEWER  Residential Low-Density
# 3              3             2-STORY 1945 & OLDER  Residential Low-Density
# 4              4             2-STORY 1946 & NEWER  Residential Low-Density
# ...          ...                              ...                      ...
# 1455        1455             2-STORY 1946 & NEWER  Residential Low-Density
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1457        1457             2-STORY 1945 & OLDER  Residential Low-Density
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# ...

# %%
real_state_data.isnull().sum().sum()
# Out:
# 0

# %%
real_state_data.to_csv("C:\\Users\\admin\\Desktop\\EDA Internship Project3\\Final Data Set.csv",index=False)

# %%
real_state_data = real_state_data.drop("Unnamed: 0", axis='columns')

# %%
outliers=[]
def find_outliers_iqr(data):
    data=sorted(data)
    q1=np.percentile(data, 25)
    q3=np.percentile(data, 75)
    iqr=q3-q1
    lwr_bound = q1-(1.5*iqr)
    upr_bound = q3+(1.5*iqr)
    for i in data:
        if(i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers

# %%
real_state_data.boxplot(column="SalePrice")
# Out:
# <Axes: >

# %%
sns.violinplot(real_state_data["Total square feet of basement area"])
# Out:
# <Axes: >

# %%
real_state_data.boxplot(column = "First Floor square feet")
plt.show()

# %%
real_state_data.head()
# Out:
#                   Type of dwelling           General Zoning  \
# 0             2-STORY 1946 & NEWER  Residential Low-Density
# 1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2             2-STORY 1946 & NEWER  Residential Low-Density
# 3             2-STORY 1945 & OLDER  Residential Low-Density
# 4             2-STORY 1946 & NEWER  Residential Low-Density
#
#    Linear feet of street  Lot size in square feet  \
# 0                     65                     8450
# 1                     80                     9600
# 2                     68                    11250
# 3                     60                     9550
# 4                     84                    14260
#
#   Type of Acess Road to Property General shape of property  \
# 0                          Paved                   Regular
# 1                          Paved                   Regular
# 2                          Paved        Slightly irregular
# ...

# %%
#Univariate Analysis of whole Data Set
real_state_data.hist (bins= 15, color="red", edgecolor = "black", linewidth= 1, xlabelsize= 8,ylabelsize=8, grid= False)
plt.tight_layout(rect=(0,0,5,5))
plt.suptitle("House price predict Univariate plot", x=0.65,y=1.25,fontsize=1)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_8364\1536625566.py:3: UserWarning: Glyph 9 (	) missing from current font.
#   plt.tight_layout(rect=(0,0,5,5))
# C:\Users\admin\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set(style="whitegrid")
fig, axes=plt.subplots(nrows=2,ncols=1,figsize=(10,8))
#Plot histogram for house Prices
sns.histplot( real_state_data["SalePrice"], kde=True, color="skyblue",ax=axes[0])
axes[0].set_title("Histogram_Sales_Prices")
axes[0].set_xlabel("SalePrice")
axes[0].set_ylabel("Frequency")
sns.kdeplot( real_state_data["SalePrice"],color="red", ax=axes[1])
axes[1].set_title("Kde of Sales Price")
axes[1].set_xlabel("SalePrice")
axes[1].set_ylabel("Density")
plt.tight_layout()
plt.show()

# %% [markdown]
# # #Multivariate Analysis

# %%
features=['SalePrice','Total rooms above grade (does not include bathrooms)','First Floor square feet',
 'econd-floor square feet','Rates the overall material', 'Rates the overall condition of the house']
sns.pairplot(real_state_data[features])
plt.suptitle("pair of Variable impacting in Sales Price",y=1.02)
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Market Trends and historical Price

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x="Original construction date",y="SalePrice",data=real_state_data,estimator="mean",errorbar=None,color="red")
plt.title("historical property")
plt.xlabel("construction")
plt.ylabel("sale price")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Coustmer Prefrences and animities

# %%
#Barplot of average house price by the Pool area 
plt.figure(figsize=(12,6))
sns.boxplot(x="Pool area in square feet",y="SalePrice",data=real_state_data)
plt.title("House Price by pool area")
plt.xlabel("Pool area ")
plt.ylabel("sale price")
plt.grid(True)
plt.show()
#Bar Plot of avererage house Price by the number of open porch area
plt.figure(figsize=(12,6))
sns.barplot(x="Open porch area in square feet",y="SalePrice",data=real_state_data)
plt.title("House Price by porch area")
plt.xlabel("Porch area")
plt.ylabel("sale price")
plt.grid(True)
plt.show()
#Barplot of average house price by the garage in car capacity
plt.figure(figsize=(12,6))
sns.barplot(x="Size of garage in car capacity",y="SalePrice",data=real_state_data)
plt.title("House Price by garage car Capacity")
plt.xlabel("cgarage in car capacity")
plt.ylabel("sale price")
plt.grid(True)
plt.show()
